# %% [markdown]
# # Latest Air Quality Index Analysis

# %% [markdown]
# # Libraires

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # loading Dataset

# %%
my_data = pd.read_csv('C:\\Users\\Talal\\Downloads\\Data\\26th_December_2023_Air_Quality_Dataset.csv')
my_data
# Out:
#         id country           state      city            station station_code  \
# 0        0   India  Andhra_Pradesh  A0ntapur          Gulzarpet        APPCB
# 1        1   India  Andhra_Pradesh  Chittoor  Gangineni Cheruvu        APPCB
# 2        2   India  Andhra_Pradesh  Tirupati           Tirumala        APPCB
# 3        3   India  Andhra_Pradesh  Tirupati           Tirumala        APPCB
# 4        4   India  Andhra_Pradesh  Tirupati           Tirumala        APPCB
# ...    ...     ...             ...       ...                ...          ...
# 3311  3311   India     West_Bengal   Kolkata           Jadavpur        WBPCB
# 3312  3312   India     West_Bengal   Kolkata   Rabindra Sarobar        WBPCB
# 3313  3313   India     West_Bengal   Kolkata   Rabindra Sarobar        WBPCB
# 3314  3314   India     West_Bengal   Kolkata   Rabindra Sarobar        WBPCB
# 3315  3315   India     West_Bengal  Siliguri               Ward        WBPCB
#
# ...

# %% [markdown]
# # Exploratory data analysis (EDA)

# %% [markdown]
# # To know some more information about our dataset

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3316 entries, 0 to 3315
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             3316 non-null   int64
#  1   country        3316 non-null   object
#  2   state          3316 non-null   object
#  3   city           3316 non-null   object
#  4   station        3316 non-null   object
#  5   station_code   3316 non-null   object
#  6   last_update    3316 non-null   object
#  7   latitude       3316 non-null   float64
#  8   longitude      3316 non-null   float64
#  9   pollutant_id   3316 non-null   object
#  10  pollutant_min  3316 non-null   int64
#  11  pollutant_max  3316 non-null   int64
#  12  pollutant_avg  3316 non-null   int64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 336.9+ KB

# %% [markdown]
# # To check null values

# %%
my_data.isnull().sum()
# Out:
# id               0
# country          0
# state            0
# city             0
# station          0
# station_code     0
# last_update      0
# latitude         0
# longitude        0
# pollutant_id     0
# pollutant_min    0
# pollutant_max    0
# pollutant_avg    0
# dtype: int64

# %% [markdown]
# # For unique values in state column

# %%
my_data.state.unique()
# Out:
# array(['Andhra_Pradesh', 'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Delhi', 'Gujarat', 'Harya0', 'Himachal Pradesh', 'Jharkhand',
#        'Kar0taka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', '0galand', 'Odisha', 'Punjab', 'Rajasthan',
#        'Tamil0du', 'Telanga0', 'Tripura', 'Uttar_Pradesh', 'Uttarakhand',
#        'West_Bengal', 'Aru0chal_Pradesh', 'Jammu_and_Kashmir',
#        'Puducherry', 'Sikkim', 'Mizoram'], dtype=object)

# %%
my_data.last_update.unique()
# Out:
# array(['26-12-2023 22:00'], dtype=object)

# %%
my_data.pollutant_id.unique()
# Out:
# array(['SO2', 'NH3', 'CO', 'OZONE', 'PM10', 'PM2.5', 'NO2'], dtype=object)

# %%
my_data.describe()
# Out:
#                 id     latitude    longitude  pollutant_min  pollutant_max  \
# count  3316.000000  3316.000000  3316.000000    3316.000000    3316.000000
# mean   1657.500000    22.769742    78.545983      38.061218     110.646261
# std     957.391073     5.407461     4.882075      55.475655     126.634146
# min       0.000000     8.514909    70.909168       0.000000       0.000000
# 25%     828.750000    19.065931    75.389600       4.000000      16.000000
# 50%    1657.500000    23.264759    77.300590      16.000000      62.000000
# 75%    2486.250000    27.194120    80.327067      47.000000     148.000000
# max    3315.000000    34.066206    94.636574     371.000000     500.000000
#
#        pollutant_avg
# count    3316.000000
# mean       69.669481
# std        85.316767
# min         0.000000
# 25%        10.000000
# 50%        36.000000
# 75%        90.000000
# max       439.000000

# %% [markdown]
# # Visualization

# %%
state_counts = my_data['state'].value_counts()
plt.figure(figsize=(10,6))
state_counts.plot(kind ='bar', color ='skyblue')
plt.title('Frequency')
plt.xlabel('States')
plt.ylabel('Count')
plt.xticks(rotation = 45, ha='right')
plt.show()

# %%
avg_pollutants = my_data.groupby('pollutant_id')['pollutant_avg'].mean()
plt.figure(figsize=(10,6))
avg_pollutants.plot(kind='bar', color='skyblue')
plt.title('Average Pollutants Across the Day')
plt.xlabel('Pollutant Type')
plt.ylabel('Average')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
avg_pollutants_state = my_data.groupby('state')['pollutant_avg'].mean()
plt.figure(figsize=(12,6))
avg_pollutants_state.plot(kind='bar', color='green')
plt.title('Average Pollutants Across the States')
plt.xlabel('States')
plt.ylabel('Average')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
avg_pollutants_state_type = my_data.groupby(['state','pollutant_id'])['pollutant_avg'].mean()
plt.figure(figsize=(12,6))
avg_pollutants_state_type.plot(kind='line', color='green')
plt.title('Different Pollutant Levels Across the States')
plt.xlabel('States')
plt.ylabel('Average')

plt.xticks(rotation=45, ha='right')
plt.show()

# %%
max_pollutants_state = my_data.groupby('state')['pollutant_max'].mean()
plt.figure(figsize=(12,6))
max_pollutants_state.plot(kind='bar', color='orange')
plt.title('Maximum Pollutants Across the States')
plt.xlabel('States')
plt.ylabel('Maximum')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
min_pollutants_state = my_data.groupby('state')['pollutant_min'].mean()
plt.figure(figsize=(12,6))
min_pollutants_state.plot(kind='line', color='purple')
plt.title('Minimum Pollutants Across the States')
plt.xlabel('States')
plt.ylabel('Minimum')
plt.xticks(rotation=45, ha='right')
plt.show()
